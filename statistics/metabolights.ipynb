# %%
# import libraries
import pandas as pd

# %%
# read in data
data = pd.read_csv('ftp://ftp.ebi.ac.uk/pub/databases/metabolights/studies/public/MTBLS449/s_mtbls449.txt', sep="\t")

# %%
data.head(3)
# Out:
#    Source Name Characteristics[organism] Term Source REF  \
# 0         1005              Homo sapiens       NCBITAXON
# 1         1007              Homo sapiens       NCBITAXON
# 2         1010              Homo sapiens       NCBITAXON
#
#                                Term Accession Number  \
# 0  http://purl.bioontology.org/ontology/NCBITAXON...
# 1  http://purl.bioontology.org/ontology/NCBITAXON...
# 2  http://purl.bioontology.org/ontology/NCBITAXON...
#
#   Characteristics[Organism part] Term Source REF.1  \
# 0                   blood plasma               BTO
# 1                   blood plasma               BTO
# 2                   blood plasma               BTO
#
#                       Term Accession Number.1       Protocol REF  Sample Name  \
# 0  http://purl.obolibrary.org/obo/BTO_0000131  Sample collection         1005
# 1  http://purl.obolibrary.org/obo/BTO_0000131  Sample collection         1007
# ...

# %% [markdown]
# ## Show unique organisms

# %%
list(data['Characteristics[organism]'].unique())
# Out:
# ['Homo sapiens']

# %% [markdown]
# ## Download measurements

# %%
measurements = pd.read_csv('ftp://ftp.ebi.ac.uk/pub/databases/metabolights/studies/public/MTBLS449/m_mtbls449_Oxylipin_mass_spectrometry_v2_maf.tsv', sep="\t")

# %%
measurements.head(3)
# Out:
#   database_identifier chemical_formula  \
# 0         CHEBI:72640         C22H32O3
# 1        CHEBI:140930         C22H32O4
# 2         CHEBI:63969         C20H34O4
#
#                                               smiles  \
# 0         CCC=C/CC=C/CC=C/C=C/C(O)CC=C/CC=C/CCC(O)=O
# 1  C(O)(=O)CC/C=C\C/C=C\C[C@@H](/C=C/C=C\C=C\[C@H...
# 2              CCCCCC=C/CC(O)C(O)CC=C/CC=C/CCCC(O)=O
#
#                                                inchi  \
# 0  InChI=1S/C22H32O3/c1-2-3-4-5-6-7-8-9-12-15-18-...
# 1  InChI=1S/C22H32O4/c1-2-3-10-15-20(23)17-12-8-9...
# 2  InChI=1S/C20H34O4/c1-2-3-4-5-9-12-15-18(21)19(...
#
#   metabolite_identification  mass_to_charge  fragmentation modifications  \
# 0                  10-HDoHE           343.2          153.0        [M-H]-
# 1           10S,17S-DiHDoHE             NaN            NaN        [M-H]-
# 2             11,12-DiHETrE             NaN            NaN        [M-H]-
#
# ...
